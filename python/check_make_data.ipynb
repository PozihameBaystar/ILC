# %%
import numpy as np
import matplotlib.pyplot as plt
from make_data import flat_curve_data1,flat_curve_data2

# %%
times = np.linspace(0,20,201)

# %%
data = flat_curve_data1(L=8,a=0.6,t=times)
plt.plot(times,data)

# %%
data = flat_curve_data2(L=5,a=0.4,t=times)
plt.plot(times,data)
