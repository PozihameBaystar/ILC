# %%
import numpy as np
import matplotlib.pyplot as plt
from make_data import flat_curve_data1,flat_curve_data2

# %%
times = np.linspace(0,10,101)
data = flat_curve_data1(L=1,a=0.5,t=times)
plt.plot(times,data)

# %%
times = np.linspace(0,10,101)
data = flat_curve_data2(L=1,a=0.3,t=times)
plt.plot(times,data)
